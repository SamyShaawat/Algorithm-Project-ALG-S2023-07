# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Read in data from CSV file, skipping the first row
df = pd.read_csv('dataset.csv')

# Create an empty graph
graph = nx.Graph()

# Add nodes for each user
users = df['usernames'].unique()
graph.add_nodes_from(users)

# Optimize edge creation
user_subs = {user: set(df.loc[df['usernames'] == user][df.columns[1:]].stack().dropna().values) for user in users}
user_subs = {user: list(subs) for user, subs in user_subs.items()}  # Convert sets to lists

# Add edges for each combination of users who participated in the same subreddit
for i, user1 in enumerate(users):
    print(f'Start user {user1}')
    user1_subs_list = user_subs[user1]
    for user2 in users[i + 1:]:
        user2_subs_list = user_subs[user2]
        common_subs = set(user1_subs_list).intersection(user2_subs_list)
        if common_subs:
            # Convert the set of common subreddits to a list
            common_subs_list = list(common_subs)
            # Exclude unsupported data values (e.g., datetime objects)
            common_subs_list = [str(sub) for sub in common_subs_list]
            graph.add_edge(user1, user2, subreddits=common_subs_list)
    print(f'Finished user {user1}')

# Set data type for 'subreddits' attribute explicitly
nx.set_edge_attributes(graph, {edge: str(graph.edges[edge]['subreddits']) for edge in graph.edges}, 'subreddits')
print("end")
# Out:
# Streaming output truncated to the last 5000 lines.
# Finished user MarcaP123
# Start user Away_Bee_8734
# Finished user Away_Bee_8734
# Start user ampsonic
# Finished user ampsonic
# Start user Flashdancer405
# Finished user Flashdancer405
# Start user WreckMyHoleDaddy
# Finished user WreckMyHoleDaddy
# Start user CackalackRunner
# Finished user CackalackRunner
# Start user lem0nwings
# Finished user lem0nwings
# Start user jm9thh
# Finished user jm9thh
# Start user nathanc98
# Finished user nathanc98
# Start user cupcakeandsweetlover
# Finished user cupcakeandsweetlover
# Start user raiigiic
# Finished user raiigiic
# Start user Yeeyeetyall
# Finished user Yeeyeetyall
# Start user Revolutionary_Act_63
# Finished user Revolutionary_Act_63
# Start user Persistence-Key459
# Finished user Persistence-Key459
# Start user rene-cumbubble
# Finished user rene-cumbubble
# Start user dancedanceevol909
# Finished user dancedanceevol909
# Start user medodoamor
# Finished user medodoamor
# Start user Albinkiiii
# Finished user Albinkiiii
# Start user Blooberton
# Finished user Blooberton
# Start user PaleOstrich
# Finished user PaleOstrich
# Start user doctormdphdmscmsw
# Finished user doctormdphdmscmsw
# Start user _toasted_toast_
# Finished user _toasted_toast_
# Start user Putrid-Inevitable720
# Finished user Putrid-Inevitable720
# Start user sarge101st
# Finished user sarge101st
# Start user emory_2001
# Finished user emory_2001
# Start user ssrabbanii
# Finished user ssrabbanii
# Start user Yoda_ofyourlife
# Finished user Yoda_ofyourlife
# Start user Interesting-Goose568
# Finished user Interesting-Goose568
# Start user yoursinglefather
# Finished user yoursinglefather
# Start user ThePsykoBunny
# Finished user ThePsykoBunny
# Start user kaygee1694
# Finished user kaygee1694
# Start user financial_freedom416
# Finished user financial_freedom416
# Start user Finessedaddy420
# Finished user Finessedaddy420
# Start user East_Cartographer888
# Finished user East_Cartographer888
# Start user Content_Craft_1747
# Finished user Content_Craft_1747
# Start user Scrub1991
# Finished user Scrub1991
# Start user triplethreat18
# Finished user triplethreat18
# Start user Lady-bug319
# Finished user Lady-bug319
# Start user rylotz
# Finished user rylotz
# Start user Sunnflwr
# Finished user Sunnflwr
# Start user akanaan5
# Finished user akanaan5
# Start user dulz93
# Finished user dulz93
# Start user karmicnerd
# Finished user karmicnerd
# Start user FoldedTwice
# Finished user FoldedTwice
# Start user watermelonpep83
# Finished user watermelonpep83
# Start user yeeet555588
# Finished user yeeet555588
# Start user toady89
# Finished user toady89
# Start user catssandwhatnot
# Finished user catssandwhatnot
# Start user Gal_gadonutt
# Finished user Gal_gadonutt
# Start user Psyk0l0ge
# Finished user Psyk0l0ge
# Start user Achengz
# Finished user Achengz
# Start user artbyak
# Finished user artbyak
# Start user TrumanB-12
# Finished user TrumanB-12
# Start user infochimp
# Finished user infochimp
# Start user alltheokonomiyakis
# Finished user alltheokonomiyakis
# Start user pinkm1lktea
# Finished user pinkm1lktea
# Start user edenbeatrix
# Finished user edenbeatrix
# Start user Pronel23
# Finished user Pronel23
# Start user LadyTerminator1
# Finished user LadyTerminator1
# Start user Chickenlovingveggie
# Finished user Chickenlovingveggie
# Start user booshybeans
# Finished user booshybeans
# Start user hmio213
# Finished user hmio213
# Start user Dependent-Film4035
# Finished user Dependent-Film4035
# Start user LJohnson1127
# Finished user LJohnson1127
# Start user doctorjekyll4
# Finished user doctorjekyll4
# Start user helpmenameit
# Finished user helpmenameit
# Start user GuiltyFishing2457
# Finished user GuiltyFishing2457
# Start user OrangeJuice225
# Finished user OrangeJuice225
# Start user Street_Hour
# Finished user Street_Hour
# Start user simplicityx29
# Finished user simplicityx29
# Start user shogun1007
# Finished user shogun1007
# Start user HannahBanana300
# Finished user HannahBanana300
# Start user Icy_Mousse_4144
# Finished user Icy_Mousse_4144
# Start user busylilmissy
# Finished user busylilmissy
# Start user magdit
# Finished user magdit
# Start user bradstreet_13
# Finished user bradstreet_13
# Start user Sleepynn
# Finished user Sleepynn
# Start user Zealousideal-Cup8249
# Finished user Zealousideal-Cup8249
# Start user SantistaGirl
# Finished user SantistaGirl
# Start user homiesbegged
# Finished user homiesbegged
# Start user Jaded_Hospital_2165
# Finished user Jaded_Hospital_2165
# Start user Marg7890
# Finished user Marg7890
# Start user Thorsten20
# Finished user Thorsten20
# Start user R0bbi99
# Finished user R0bbi99
# Start user Objective-Tea-3070
# Finished user Objective-Tea-3070
# Start user Both_Meal6691
# Finished user Both_Meal6691
# Start user just1morepag3
# Finished user just1morepag3
# Start user mae_ow
# Finished user mae_ow
# Start user mybusinessnotyoursok
# Finished user mybusinessnotyoursok
# Start user CommunicationNo7772
# Finished user CommunicationNo7772
# Start user Stringel
# Finished user Stringel
# Start user manhandsmcghee
# Finished user manhandsmcghee
# Start user Low-Arm-9440
# Finished user Low-Arm-9440
# Start user looper33
# Finished user looper33
# Start user so_fetch567
# Finished user so_fetch567
# Start user Throwaway19473729103
# Finished user Throwaway19473729103
# Start user Basic_Ad4562
# Finished user Basic_Ad4562
# Start user justmeAlonekitty
# Finished user justmeAlonekitty
# Start user Routine_Ad1865
# Finished user Routine_Ad1865
# Start user philoveritas
# Finished user philoveritas
# Start user beachbumbaby9
# Finished user beachbumbaby9
# Start user luke8ball
# Finished user luke8ball
# Start user tnvrmasquerade
# Finished user tnvrmasquerade
# Start user Any_Engineering336
# Finished user Any_Engineering336
# Start user WWCPhelpsD
# Finished user WWCPhelpsD
# Start user RNReef
# Finished user RNReef
# Start user Only_My_Dog_Loves_Me
# Finished user Only_My_Dog_Loves_Me
# Start user Pakirambo2k21
# Finished user Pakirambo2k21
# Start user jadaha972
# Finished user jadaha972
# Start user soulshadow21
# Finished user soulshadow21
# Start user Rainyferret
# Finished user Rainyferret
# Start user SIGABRT6
# Finished user SIGABRT6
# Start user Zizzlow
# Finished user Zizzlow
# Start user Willing-Sprinkles576
# Finished user Willing-Sprinkles576
# Start user enochianchant
# Finished user enochianchant
# Start user matt9191
# Finished user matt9191
# Start user saycheese_
# Finished user saycheese_
# Start user ace6789
# Finished user ace6789
# Start user doubleuu88
# Finished user doubleuu88
# Start user sayana_saini
# Finished user sayana_saini
# Start user Reasonable_Employ588
# Finished user Reasonable_Employ588
# Start user White_crow606
# Finished user White_crow606
# Start user Zealousideal-Kale532
# Finished user Zealousideal-Kale532
# Start user KetameanQueen
# Finished user KetameanQueen
# Start user No_Asparagus_
# Finished user No_Asparagus_
# Start user TrblShooter43
# Finished user TrblShooter43
# Start user stainedsalt
# Finished user stainedsalt
# Start user These_Yak_1651
# Finished user These_Yak_1651
# Start user menthol-drops
# Finished user menthol-drops
# Start user shaolinfunky
# Finished user shaolinfunky
# Start user AHappyTyphlosion
# Finished user AHappyTyphlosion
# Start user PotterWhoLock01
# Finished user PotterWhoLock01
# Start user Comprehensive-Pin506
# Finished user Comprehensive-Pin506
# Start user chompingchickys
# Finished user chompingchickys
# Start user shane-21
# Finished user shane-21
# Start user Crazy-Ad-1849
# Finished user Crazy-Ad-1849
# Start user Mikoshumi
# Finished user Mikoshumi
# Start user AngryBacon13
# Finished user AngryBacon13
# Start user lauraaa321123
# Finished user lauraaa321123
# Start user snowcold0
# Finished user snowcold0
# Start user ooohcoffee
# Finished user ooohcoffee
# Start user Triggerboom0306
# Finished user Triggerboom0306
# Start user Calm_Neighborhood160
# Finished user Calm_Neighborhood160
# Start user Peacemaker_69
# Finished user Peacemaker_69
# Start user 4everonlyninja
# Finished user 4everonlyninja
# Start user ObjectiveRun8633
# Finished user ObjectiveRun8633
# Start user QuickAd1559
# Finished user QuickAd1559
# Start user da3sy
# Finished user da3sy
# Start user dk12-85
# Finished user dk12-85
# Start user santickles
# Finished user santickles
# Start user findikezmesi
# Finished user findikezmesi
# Start user Apprehensive-Tax1923
# Finished user Apprehensive-Tax1923
# Start user ariellross
# Finished user ariellross
# Start user Funny_winds
# Finished user Funny_winds
# Start user pillowtalkingtonoone
# Finished user pillowtalkingtonoone
# Start user ayewheezy
# Finished user ayewheezy
# Start user ButterscotchWrong932
# Finished user ButterscotchWrong932
# Start user odinthepup
# Finished user odinthepup
# Start user GhostWatcher0889
# Finished user GhostWatcher0889
# Start user charlotteraedrake
# Finished user charlotteraedrake
# Start user SendNudez5405050484
# Finished user SendNudez5405050484
# Start user Reddit-Sama-
# Finished user Reddit-Sama-
# Start user central2nowherebaby
# Finished user central2nowherebaby
# Start user payamsaremi
# Finished user payamsaremi
# Start user Ace035
# Finished user Ace035
# Start user princeparakeet
# Finished user princeparakeet
# Start user LauraPalmer93
# Finished user LauraPalmer93
# Start user Fun_Cucumber1382
# Finished user Fun_Cucumber1382
# Start user stolentrihardcx
# Finished user stolentrihardcx
# Start user TheGoldenGooseTurd
# Finished user TheGoldenGooseTurd
# Start user Old_Manufacturer4878
# Finished user Old_Manufacturer4878
# Start user Smiley_Irving
# Finished user Smiley_Irving
# Start user Heylookanickel
# Finished user Heylookanickel
# Start user Mond_yAddams
# Finished user Mond_yAddams
# Start user AugustStan
# Finished user AugustStan
# Start user davidpaigemusic
# Finished user davidpaigemusic
# Start user WatisUsername
# Finished user WatisUsername
# Start user roundtriptraveler
# Finished user roundtriptraveler
# Start user ZingierOne
# Finished user ZingierOne
# Start user BedPractical4184
# Finished user BedPractical4184
# Start user douggold11
# Finished user douggold11
# Start user ThrowRAidkwnsms
# Finished user ThrowRAidkwnsms
# Start user t109j
# Finished user t109j
# Start user meltedfigs
# Finished user meltedfigs
# Start user SimpleBoi90
# Finished user SimpleBoi90
# Start user Thduun
# Finished user Thduun
# Start user anglerfish527
# Finished user anglerfish527
# Start user Low-Decision-8513
# Finished user Low-Decision-8513
# Start user IError413
# Finished user IError413
# Start user Tribalbob
# Finished user Tribalbob
# Start user Happy-Reputation-512
# Finished user Happy-Reputation-512
# Start user randomnetz
# Finished user randomnetz
# Start user 8Stone
# Finished user 8Stone
# Start user utahbed
# Finished user utahbed
# Start user MatthewRTRCT
# Finished user MatthewRTRCT
# Start user thebageljew
# Finished user thebageljew
# Start user mrc1993
# Finished user mrc1993
# Start user BCN_A
# Finished user BCN_A
# Start user BKsparkles
# Finished user BKsparkles
# Start user caracareless
# Finished user caracareless
# Start user salcander
# Finished user salcander
# Start user Mjrllcc
# Finished user Mjrllcc
# Start user comicreliefboy
# Finished user comicreliefboy
# Start user ImaginaryDesigner235
# Finished user ImaginaryDesigner235
# Start user Consistent_Picture98
# Finished user Consistent_Picture98
# Start user BigHugFromaStranger
# Finished user BigHugFromaStranger
# Start user StillClimbing
# Finished user StillClimbing
# Start user Lazy_Relationship_15
# Finished user Lazy_Relationship_15
# Start user JosephMarro
# Finished user JosephMarro
# Start user briantravelman
# Finished user briantravelman
# Start user k07ya
# Finished user k07ya
# Start user MCGA2016
# Finished user MCGA2016
# Start user S-MINT
# Finished user S-MINT
# Start user wino_whynot
# Finished user wino_whynot
# Start user pbblueroom
# Finished user pbblueroom
# Start user ssg_partners
# Finished user ssg_partners
# Start user PsychoCuteClingy
# Finished user PsychoCuteClingy
# Start user Rad-Cabbage
# Finished user Rad-Cabbage
# Start user mb72378
# Finished user mb72378
# Start user -Babel_Fish-
# Finished user -Babel_Fish-
# Start user treesofthemind
# Finished user treesofthemind
# Start user Palmleaves_
# Finished user Palmleaves_
# Start user Substantial-Fig2184
# Finished user Substantial-Fig2184
# Start user Grouchy_Ad_6333
# Finished user Grouchy_Ad_6333
# Start user Kieffer899
# Finished user Kieffer899
# Start user rawSingularity
# Finished user rawSingularity
# Start user thrown-away-thoughts
# Finished user thrown-away-thoughts
# Start user The_Wandering_Chris
# Finished user The_Wandering_Chris
# Start user Humble-Yesterday-
# Finished user Humble-Yesterday-
# Start user ma_dian
# Finished user ma_dian
# Start user spradc0812
# Finished user spradc0812
# Start user NoddingWalrus
# Finished user NoddingWalrus
# Start user JJ10896
# Finished user JJ10896
# Start user Pikminmania2
# Finished user Pikminmania2
# Start user tonnertron
# Finished user tonnertron
# Start user nomadickid942
# Finished user nomadickid942
# Start user 3rdAccount123
# Finished user 3rdAccount123
# Start user Longjumping_Fold_369
# Finished user Longjumping_Fold_369
# Start user CompetitiveAd6420
# Finished user CompetitiveAd6420
# Start user Churro_The_fish_Girl
# Finished user Churro_The_fish_Girl
# Start user AwayWeThrown
# Finished user AwayWeThrown
# Start user Disastrous_Ad_8882
# Finished user Disastrous_Ad_8882
# Start user PsychologicalPanda84
# Finished user PsychologicalPanda84
# Start user brandideer
# Finished user brandideer
# Start user cocodinosaur
# Finished user cocodinosaur
# Start user usr3nmev3
# Finished user usr3nmev3
# Start user BeginningTypical
# Finished user BeginningTypical
# Start user kszo787
# Finished user kszo787
# Start user Background-Subject76
# Finished user Background-Subject76
# Start user Tiny_Cartographer_53
# Finished user Tiny_Cartographer_53
# Start user Hemingsway
# Finished user Hemingsway
# Start user peachwilkins5
# Finished user peachwilkins5
# Start user absofruitley
# Finished user absofruitley
# Start user Nems017
# Finished user Nems017
# Start user ProfessionalOven5677
# Finished user ProfessionalOven5677
# Start user Sustainable_Coffee94
# Finished user Sustainable_Coffee94
# Start user upontruebois
# Finished user upontruebois
# Start user Nerd803
# Finished user Nerd803
# Start user psrwo
# Finished user psrwo
# Start user sunflowersroses
# Finished user sunflowersroses
# Start user craveforcooking
# Finished user craveforcooking
# Start user Poofpafpoof
# Finished user Poofpafpoof
# Start user Purge_999
# Finished user Purge_999
# Start user smolbibeans
# Finished user smolbibeans
# Start user frenchfriesnotfrench
# Finished user frenchfriesnotfrench
# Start user LordBucketHead69
# Finished user LordBucketHead69
# Start user rachael-111
# Finished user rachael-111
# Start user dejvmastejn
# Finished user dejvmastejn
# Start user TheWallofFur
# Finished user TheWallofFur
# Start user ryadre
# Finished user ryadre
# Start user 2ndgenerationcatlady
# Finished user 2ndgenerationcatlady
# Start user thatgreenfuture
# Finished user thatgreenfuture
# Start user RollingFeckNugget
# Finished user RollingFeckNugget
# Start user SolutionLeading
# Finished user SolutionLeading
# Start user The_Empress
# Finished user The_Empress
# Start user NeonYellow00
# Finished user NeonYellow00
# Start user tnk13
# Finished user tnk13
# Start user graymoon_25
# Finished user graymoon_25
# Start user Briskteas
# Finished user Briskteas
# Start user pickles-dill
# Finished user pickles-dill
# Start user nevertotwice_
# Finished user nevertotwice_
# Start user Super_Bright
# Finished user Super_Bright
# Start user RitaBonanza
# Finished user RitaBonanza
# Start user phhhhhhbt
# Finished user phhhhhhbt
# Start user Michaelscott555
# Finished user Michaelscott555
# Start user catmss24
# Finished user catmss24
# Start user Frostypumpkin22
# Finished user Frostypumpkin22
# Start user technicolordomingo
# Finished user technicolordomingo
# Start user km33l
# Finished user km33l
# Start user lurketta
# Finished user lurketta
# Start user Ok-Estate-3531
# Finished user Ok-Estate-3531
# Start user Sudden_Baseball_1605
# Finished user Sudden_Baseball_1605
# Start user adorientem88
# Finished user adorientem88
# Start user andy12321
# Finished user andy12321
# Start user shiny1015
# Finished user shiny1015
# Start user -salisbury-
# Finished user -salisbury-
# Start user racquelious
# Finished user racquelious
# Start user MrPotter1492
# Finished user MrPotter1492
# Start user redheadbed0
# Finished user redheadbed0
# Start user live4film87
# Finished user live4film87
# Start user kacpiwiewiu
# Finished user kacpiwiewiu
# Start user kebabai
# Finished user kebabai
# Start user Leadership_Calm
# Finished user Leadership_Calm
# Start user fickle_pcle
# Finished user fickle_pcle
# Start user verboseamoeba
# Finished user verboseamoeba
# Start user AssociationJumpy
# Finished user AssociationJumpy
# Start user Look_a_skylark
# Finished user Look_a_skylark
# Start user kam_redditor
# Finished user kam_redditor
# Start user TheGreat_N8
# Finished user TheGreat_N8
# Start user djangoo7
# Finished user djangoo7
# Start user Traditional_Safe_654
# Finished user Traditional_Safe_654
# Start user EfficientTaro3393
# Finished user EfficientTaro3393
# Start user kitcat_kittycat
# Finished user kitcat_kittycat
# Start user National_Bag1508
# Finished user National_Bag1508
# Start user SnortingToad
# Finished user SnortingToad
# Start user No_Neck8552
# Finished user No_Neck8552
# Start user tenant1313
# Finished user tenant1313
# Start user Wrong_Carpenter913
# Finished user Wrong_Carpenter913
# Start user onetwothreefour27
# Finished user onetwothreefour27
# Start user nammerones
# Finished user nammerones
# Start user SmartyPantsHippie
# Finished user SmartyPantsHippie
# Start user champagne_epigram
# Finished user champagne_epigram
# Start user AliShlaibeq
# Finished user AliShlaibeq
# Start user trezorowski
# Finished user trezorowski
# Start user fartingfan
# Finished user fartingfan
# Start user DrNiles_Crane
# Finished user DrNiles_Crane
# Start user KillBosby
# Finished user KillBosby
# Start user QuelynD
# Finished user QuelynD
# Start user upbeatbeans
# Finished user upbeatbeans
# Start user DryBlackberry1445
# Finished user DryBlackberry1445
# Start user PossiblyA_Bot
# Finished user PossiblyA_Bot
# Start user Wicket257
# Finished user Wicket257
# Start user shantiteuta
# Finished user shantiteuta
# Start user Shot_Company8941
# Finished user Shot_Company8941
# Start user Mannimarco117
# Finished user Mannimarco117
# Start user ComradeArchie101
# Finished user ComradeArchie101
# Start user butterflywithbullets
# Finished user butterflywithbullets
# Start user Economy-Direction198
# Finished user Economy-Direction198
# Start user PM_ME_A_SHITTY_POEM
# Finished user PM_ME_A_SHITTY_POEM
# Start user Only-Midnight9817
# Finished user Only-Midnight9817
# Start user skripskrip
# Finished user skripskrip
# Start user reikalykos
# Finished user reikalykos
# Start user smnmsk
# Finished user smnmsk
# Start user OverallPhotograph353
# Finished user OverallPhotograph353
# Start user Ceasedx
# Finished user Ceasedx
# Start user gobblegobblerr
# Finished user gobblegobblerr
# Start user Outrageous-Divide872
# Finished user Outrageous-Divide872
# Start user Maleficent-Number-10
# Finished user Maleficent-Number-10
# Start user littleYipon
# Finished user littleYipon
# Start user ExtremeCauliflower76
# Finished user ExtremeCauliflower76
# Start user Ecstatic_Swordfish83
# Finished user Ecstatic_Swordfish83
# Start user SunnyBanana276
# Finished user SunnyBanana276
# Start user shkvarkl
# Finished user shkvarkl
# Start user jutley1991
# Finished user jutley1991
# Start user chillylemonwater
# Finished user chillylemonwater
# Start user dazeemayne16
# Finished user dazeemayne16
# Start user StoneNight48032
# Finished user StoneNight48032
# Start user Euphoric_Parsley_
# Finished user Euphoric_Parsley_
# Start user toastmalawn
# Finished user toastmalawn
# Start user Digital_Disimpaction
# Finished user Digital_Disimpaction
# Start user naijaboyy16
# Finished user naijaboyy16
# Start user nicehappydog
# Finished user nicehappydog
# Start user potallegta
# Finished user potallegta
# Start user plugofnd
# Finished user plugofnd
# Start user zopidrone
# Finished user zopidrone
# Start user AnubisUK
# Finished user AnubisUK
# Start user Tacocatbr
# Finished user Tacocatbr
# Start user Incoming_Redditeer
# Finished user Incoming_Redditeer
# Start user NataliaFox69
# Finished user NataliaFox69
# Start user signgain82
# Finished user signgain82
# Start user Nic727
# Finished user Nic727
# Start user hannahb7654
# Finished user hannahb7654
# Start user EraaHeraa
# Finished user EraaHeraa
# Start user Boaty_McBoatface__
# Finished user Boaty_McBoatface__
# Start user sftospo
# Finished user sftospo
# Start user Irotaru
# Finished user Irotaru
# Start user Braap823
# Finished user Braap823
# Start user Vericus
# Finished user Vericus
# Start user hereforthetalk97
# Finished user hereforthetalk97
# Start user Uter_Zorker_
# Finished user Uter_Zorker_
# Start user -lover-of-books-
# Finished user -lover-of-books-
# Start user BeneficialMusician96
# Finished user BeneficialMusician96
# Start user Ambitious_Peacock
# Finished user Ambitious_Peacock
# Start user ebonyslimm
# Finished user ebonyslimm
# Start user Moist_Language_9144
# Finished user Moist_Language_9144
# Start user whytea2021
# Finished user whytea2021
# Start user BeccaDora
# Finished user BeccaDora
# Start user CapitalFill4
# Finished user CapitalFill4
# Start user Tylph57
# Finished user Tylph57
# Start user Electronic-Fennel824
# Finished user Electronic-Fennel824
# Start user jasminnneeee
# Finished user jasminnneeee
# Start user Ok-Lynx4333
# Finished user Ok-Lynx4333
# Start user Main-Savings-4765
# Finished user Main-Savings-4765
# Start user aebulbul
# Finished user aebulbul
# Start user traveleranonymous
# Finished user traveleranonymous
# Start user machinimachu
# Finished user machinimachu
# Start user xn_nx
# Finished user xn_nx
# Start user word_vomiter
# Finished user word_vomiter
# Start user aatukaal_paaya
# Finished user aatukaal_paaya
# Start user firstnamemiddle
# Finished user firstnamemiddle
# Start user veevvavv
# Finished user veevvavv
# Start user bluemonkey1369
# Finished user bluemonkey1369
# Start user PropertyRepulsive712
# Finished user PropertyRepulsive712
# Start user Cartersamps
# Finished user Cartersamps
# Start user Spicy_CC
# Finished user Spicy_CC
# Start user ironwood18
# Finished user ironwood18
# Start user creamedpeaches
# Finished user creamedpeaches
# Start user erigby927
# Finished user erigby927
# Start user Alone_Figure3480
# Finished user Alone_Figure3480
# Start user amoderndaypeasant
# Finished user amoderndaypeasant
# Start user hustler_amelia
# Finished user hustler_amelia
# Start user phils83
# Finished user phils83
# Start user DentalDamDilemma
# Finished user DentalDamDilemma
# Start user slottypippen
# Finished user slottypippen
# Start user olddog1092
# Finished user olddog1092
# Start user rishored1ve
# Finished user rishored1ve
# Start user NoIndividual7693
# Finished user NoIndividual7693
# Start user tex_mv
# Finished user tex_mv
# Start user Ok_Refrigerator6569
# Finished user Ok_Refrigerator6569
# Start user fabridiross
# Finished user fabridiross
# Start user no-kingss
# Finished user no-kingss
# Start user koknbals
# Finished user koknbals
# Start user wondoring
# Finished user wondoring
# Start user TouchWeak4961
# Finished user TouchWeak4961
# Start user 96hov
# Finished user 96hov
# Start user autumngloss
# Finished user autumngloss
# Start user Specialist-Remote-91
# Finished user Specialist-Remote-91
# Start user Shiiroo_01
# Finished user Shiiroo_01
# Start user doublehammer
# Finished user doublehammer
# Start user taconado
# Finished user taconado
# Start user johneiun1502
# Finished user johneiun1502
# Start user EmPot94
# Finished user EmPot94
# Start user Matrin123
# Finished user Matrin123
# Start user Best_Protection6663
# Finished user Best_Protection6663
# Start user apolj777
# Finished user apolj777
# Start user imalamebutt
# Finished user imalamebutt
# Start user DetroitsGoingToWin
# Finished user DetroitsGoingToWin
# Start user unspun66
# Finished user unspun66
# Start user Foreign_Topic
# Finished user Foreign_Topic
# Start user Tigerjuice249
# Finished user Tigerjuice249
# Start user Platyhelminthes88
# Finished user Platyhelminthes88
# Start user okfine_illbite
# Finished user okfine_illbite
# Start user en-ty
# Finished user en-ty
# Start user aliashhha
# Finished user aliashhha
# Start user Taoist_Viking
# Finished user Taoist_Viking
# Start user Smart-Bag-6270
# Finished user Smart-Bag-6270
# Start user ouiouicipoftea
# Finished user ouiouicipoftea
# Start user ValueDry3902
# Finished user ValueDry3902
# Start user bobogator
# Finished user bobogator
# Start user YonatanShofty
# Finished user YonatanShofty
# Start user spaghetticat1256
# Finished user spaghetticat1256
# Start user twohatstoowhack
# Finished user twohatstoowhack
# Start user Franceseye
# Finished user Franceseye
# Start user Erin19860106
# Finished user Erin19860106
# Start user Ok_Neighborhood3336
# Finished user Ok_Neighborhood3336
# Start user runningplantlady
# Finished user runningplantlady
# Start user jloafy
# Finished user jloafy
# Start user One-Hour-4119
# Finished user One-Hour-4119
# Start user lynzpenny
# Finished user lynzpenny
# Start user MeepingMeeps
# Finished user MeepingMeeps
# Start user -Hiisi-
# Finished user -Hiisi-
# Start user whatisfoolycooly
# Finished user whatisfoolycooly
# Start user colossalmickey
# Finished user colossalmickey
# Start user nowheresville99
# Finished user nowheresville99
# Start user Hsb129
# Finished user Hsb129
# Start user Beygood95
# Finished user Beygood95
# Start user halo_halo_ako
# Finished user halo_halo_ako
# Start user InNatureTeas01
# Finished user InNatureTeas01
# Start user LazzyChick
# Finished user LazzyChick
# Start user MARCUSFUCKINGMUMFORD
# Finished user MARCUSFUCKINGMUMFORD
# Start user Throwaway041897
# Finished user Throwaway041897
# Start user DueDiligence1910
# Finished user DueDiligence1910
# Start user pistolpeter1111
# Finished user pistolpeter1111
# Start user Bloodyhell_666
# Finished user Bloodyhell_666
# Start user papajoe2510
# Finished user papajoe2510
# Start user kinvoki
# Finished user kinvoki
# Start user LSspiral
# Finished user LSspiral
# Start user Brasi93
# Finished user Brasi93
# Start user megm8
# Finished user megm8
# Start user cptmiller001
# Finished user cptmiller001
# Start user Silver_Shallot4926
# Finished user Silver_Shallot4926
# Start user tomdeals
# Finished user tomdeals
# Start user Shushesha
# Finished user Shushesha
# Start user RADToronto
# Finished user RADToronto
# Start user igotsharingan
# Finished user igotsharingan
# Start user AHomelessWalrus
# Finished user AHomelessWalrus
# Start user compulsiveranter
# Finished user compulsiveranter
# Start user slimdog
# Finished user slimdog
# Start user Coriolys12
# Finished user Coriolys12
# Start user chuck1026
# Finished user chuck1026
# Start user ApplesandAltos
# Finished user ApplesandAltos
# Start user Inferno_Trigger
# Finished user Inferno_Trigger
# Start user nzward
# Finished user nzward
# Start user petra0212
# Finished user petra0212
# Start user Prestigious-Step1264
# Finished user Prestigious-Step1264
# Start user Zealousideal-Figure5
# Finished user Zealousideal-Figure5
# Start user darrianmorgan
# Finished user darrianmorgan
# Start user ShadowMonarch_228
# Finished user ShadowMonarch_228
# Start user Low-Alfalfa-9270
# Finished user Low-Alfalfa-9270
# Start user boognickrising
# Finished user boognickrising
# Start user dubyanue
# Finished user dubyanue
# Start user caseyrobinson2
# Finished user caseyrobinson2
# Start user laurrichh
# Finished user laurrichh
# Start user ubaidnoor
# Finished user ubaidnoor
# Start user wyf88
# Finished user wyf88
# Start user MoistOrganization514
# Finished user MoistOrganization514
# Start user ResearchRick
# Finished user ResearchRick
# Start user TrickEase
# Finished user TrickEase
# Start user _sarah_bellum_
# Finished user _sarah_bellum_
# Start user blinq05
# Finished user blinq05
# Start user dc122186
# Finished user dc122186
# Start user asian_clem1
# Finished user asian_clem1
# Start user maxanier
# Finished user maxanier
# Start user nizamom
# Finished user nizamom
# Start user discojesus7
# Finished user discojesus7
# Start user goldengv
# Finished user goldengv
# Start user welldressedpepe
# Finished user welldressedpepe
# Start user Lapzong
# Finished user Lapzong
# Start user saint_leonard
# Finished user saint_leonard
# Start user H2Okie
# Finished user H2Okie
# Start user whateverr27
# Finished user whateverr27
# Start user Mustanghorse1
# Finished user Mustanghorse1
# Start user Own-Preparation-4269
# Finished user Own-Preparation-4269
# Start user kc522
# Finished user kc522
# Start user wolfeybutt
# Finished user wolfeybutt
# Start user yazmin_nazari
# Finished user yazmin_nazari
# Start user Donthatecelebrate
# Finished user Donthatecelebrate
# Start user Lynny360
# Finished user Lynny360
# Start user Manistudios
# Finished user Manistudios
# Start user Dollypartonseyelash
# Finished user Dollypartonseyelash
# Start user babykoala3
# Finished user babykoala3
# Start user OliviaDaae2000
# Finished user OliviaDaae2000
# Start user East-Alfalfa-7856
# Finished user East-Alfalfa-7856
# Start user deva1994
# Finished user deva1994
# Start user voraciousreads
# Finished user voraciousreads
# Start user MasterM001
# Finished user MasterM001
# Start user Dylanthealienyf
# Finished user Dylanthealienyf
# Start user FeministMars
# Finished user FeministMars
# Start user leqsii
# Finished user leqsii
# Start user Affectionate_Bug613
# Finished user Affectionate_Bug613
# Start user Key_Friendship_4425
# Finished user Key_Friendship_4425
# Start user SlowFatHusky
# Finished user SlowFatHusky
# Start user Major-Permission-435
# Finished user Major-Permission-435
# Start user Amazing_Produce3463
# Finished user Amazing_Produce3463
# Start user yourfriskeekittee
# Finished user yourfriskeekittee
# Start user BeaGilmore
# Finished user BeaGilmore
# Start user hamishkm
# Finished user hamishkm
# Start user Nice-Explanation-138
# Finished user Nice-Explanation-138
# Start user CooLerThanU0701
# Finished user CooLerThanU0701
# Start user mkc6918
# Finished user mkc6918
# Start user turnipsandcarrots
# Finished user turnipsandcarrots
# Start user Lr8s5sb7
# Finished user Lr8s5sb7
# Start user Advisor_Grouchy
# Finished user Advisor_Grouchy
# Start user Good_Week
# Finished user Good_Week
# Start user Yankees-player27
# Finished user Yankees-player27
# Start user layspringles
# Finished user layspringles
# Start user RandomAccessMemoriez
# Finished user RandomAccessMemoriez
# Start user bulbasaurousity
# Finished user bulbasaurousity
# Start user Available_Essay_1652
# Finished user Available_Essay_1652
# Start user goose_ws
# Finished user goose_ws
# Start user Cozysophie
# Finished user Cozysophie
# Start user onemantwohands
# Finished user onemantwohands
# Start user No_Strain9708
# Finished user No_Strain9708
# Start user Rominv16
# Finished user Rominv16
# Start user ger_crypto
# Finished user ger_crypto
# Start user pbkisthesaddestpug
# Finished user pbkisthesaddestpug
# Start user yellowhelix
# Finished user yellowhelix
# Start user her3nthere
# Finished user her3nthere
# Start user EnvironmentalGas4045
# Finished user EnvironmentalGas4045
# Start user ttnn5876
# Finished user ttnn5876
# Start user 7Thanks
# Finished user 7Thanks
# Start user Radiant_Device_502
# Finished user Radiant_Device_502
# Start user jkelly1559
# Finished user jkelly1559
# Start user Dodgy1971
# Finished user Dodgy1971
# Start user SarahTO1
# Finished user SarahTO1
# Start user CaptainAwwsum
# Finished user CaptainAwwsum
# Start user RespectedPath
# Finished user RespectedPath
# Start user crazygianttiger
# Finished user crazygianttiger
# Start user bchap72
# Finished user bchap72
# Start user SoulfulBeing
# Finished user SoulfulBeing
# Start user Yunnie_Elle
# Finished user Yunnie_Elle
# Start user WellHungStranger
# Finished user WellHungStranger
# Start user JakeTinners
# Finished user JakeTinners
# Start user davidpetrache
# Finished user davidpetrache
# Start user 2point2lbs
# Finished user 2point2lbs
# Start user GragasBellybutton
# Finished user GragasBellybutton
# Start user FlyingPotatoGirl
# Finished user FlyingPotatoGirl
# Start user zennie4
# Finished user zennie4
# Start user Freck2392
# Finished user Freck2392
# Start user EvergreenGem
# Finished user EvergreenGem
# Start user WSBTurnipGod
# Finished user WSBTurnipGod
# Start user cozy_sweatsuit
# Finished user cozy_sweatsuit
# Start user BigFatRod
# Finished user BigFatRod
# Start user MoistManufacturer946
# Finished user MoistManufacturer946
# Start user Mission-Ad-2776
# Finished user Mission-Ad-2776
# Start user sunny2098
# Finished user sunny2098
# Start user Capital_Following769
# Finished user Capital_Following769
# Start user bbjackson
# Finished user bbjackson
# Start user Vitmir97
# Finished user Vitmir97
# Start user A-Jay-0525
# Finished user A-Jay-0525
# Start user Omfgjustpickaname
# Finished user Omfgjustpickaname
# Start user Ok-Door6810
# Finished user Ok-Door6810
# Start user charliehunt
# Finished user charliehunt
# Start user brolydiver
# Finished user brolydiver
# Start user sashann19
# Finished user sashann19
# Start user Wooden_Service1977
# Finished user Wooden_Service1977
# Start user StallOfDuty
# Finished user StallOfDuty
# Start user ShotintheDark_258
# Finished user ShotintheDark_258
# Start user mutad0r
# Finished user mutad0r
# Start user WretchedRatGirl
# Finished user WretchedRatGirl
# Start user GrapesGoGsxr
# Finished user GrapesGoGsxr
# Start user sudointj
# Finished user sudointj
# Start user Agitated_Mind_7562
# Finished user Agitated_Mind_7562
# Start user gkollman18
# Finished user gkollman18
# Start user crazy__paving
# Finished user crazy__paving
# Start user aribanerji
# Finished user aribanerji
# Start user Maleficent_Cash909
# Finished user Maleficent_Cash909
# Start user weeitsvi
# Finished user weeitsvi
# Start user ActAffectionate4930
# Finished user ActAffectionate4930
# Start user Panther90
# Finished user Panther90
# Start user otterpoppys
# Finished user otterpoppys
# Start user Crumpet2021
# Finished user Crumpet2021
# Start user BrazilianDude91
# Finished user BrazilianDude91
# Start user leadfoot9
# Finished user leadfoot9
# Start user onemanmelee
# Finished user onemanmelee
# Start user Titfortat101
# Finished user Titfortat101
# Start user EntertainerNo11
# Finished user EntertainerNo11
# Start user mentallydissolved
# Finished user mentallydissolved
# Start user Bxcr
# Finished user Bxcr
# Start user Lazy_Garbage_5472
# Finished user Lazy_Garbage_5472
# Start user xStriderx_
# Finished user xStriderx_
# Start user ledaciousschmitt
# Finished user ledaciousschmitt
# Start user Notlad1717
# Finished user Notlad1717
# Start user Due_Series9569
# Finished user Due_Series9569
# Start user whooreddit
# Finished user whooreddit
# Start user weeazyy
# Finished user weeazyy
# Start user David44357
# Finished user David44357
# Start user coolPineapple07
# Finished user coolPineapple07
# Start user No-Salad4764
# Finished user No-Salad4764
# Start user Scott_1410
# Finished user Scott_1410
# Start user ARrulz
# Finished user ARrulz
# Start user Ggdukas
# Finished user Ggdukas
# Start user Chevus
# Finished user Chevus
# Start user ShinyMachamp
# Finished user ShinyMachamp
# Start user Yenick
# Finished user Yenick
# Start user LR0989
# Finished user LR0989
# Start user Mother_Strategy9309
# Finished user Mother_Strategy9309
# Start user flykol
# Finished user flykol
# Start user Zbreeze818
# Finished user Zbreeze818
# Start user notsry4brokenenglish
# Finished user notsry4brokenenglish
# Start user Potential-Theme-4531
# Finished user Potential-Theme-4531
# Start user random_strange_girl
# Finished user random_strange_girl
# Start user OkRelationship2001
# Finished user OkRelationship2001
# Start user altacct03
# Finished user altacct03
# Start user j0hnftw
# Finished user j0hnftw
# Start user amayain
# Finished user amayain
# Start user BigHowski
# Finished user BigHowski
# Start user triplehhh101993
# Finished user triplehhh101993
# Start user Legitimate-Peanut277
# Finished user Legitimate-Peanut277
# Start user RoastMasterShawn
# Finished user RoastMasterShawn
# Start user an000000n
# Finished user an000000n
# Start user MamaLuke13
# Finished user MamaLuke13
# Start user Turneywo
# Finished user Turneywo
# Start user huntingrum
# Finished user huntingrum
# Start user asoundusername
# Finished user asoundusername
# Start user roastedcinnamon
# Finished user roastedcinnamon
# Start user quiyassino
# Finished user quiyassino
# Start user londonpostie
# Finished user londonpostie
# Start user Lonely_December
# Finished user Lonely_December
# Start user Superawesomecoolman
# Finished user Superawesomecoolman
# Start user gomerqc
# Finished user gomerqc
# Start user GoldenTeacher_
# Finished user GoldenTeacher_
# Start user Mysterious_Push474
# Finished user Mysterious_Push474
# Start user No_Zookeepergame_27
# Finished user No_Zookeepergame_27
# Start user stinkymalinky
# Finished user stinkymalinky
# Start user jazzneel
# Finished user jazzneel
# Start user damaxk
# Finished user damaxk
# Start user amazingpacman
# Finished user amazingpacman
# Start user terryfahrenheit
# Finished user terryfahrenheit
# Start user Somnioo
# Finished user Somnioo
# Start user SeaweedHeavy3789
# Finished user SeaweedHeavy3789
# Start user savetheuspspsps
# Finished user savetheuspspsps
# Start user DV2FOX
# Finished user DV2FOX
# Start user da_engineer22
# Finished user da_engineer22
# Start user RubLeather9865
# Finished user RubLeather9865
# Start user basilmint29
# Finished user basilmint29
# Start user bradys25
# Finished user bradys25
# Start user Scorpio-power
# Finished user Scorpio-power
# Start user ContractNo4783
# Finished user ContractNo4783
# Start user zoomatn
# Finished user zoomatn
# Start user InexperiencedCoconut
# Finished user InexperiencedCoconut
# Start user EmilyfromMiami
# Finished user EmilyfromMiami
# Start user FlashSkyNews
# Finished user FlashSkyNews
# Start user bigtripper35486
# Finished user bigtripper35486
# Start user ThatBmanGuy
# Finished user ThatBmanGuy
# Start user Christodude
# Finished user Christodude
# Start user raags
# Finished user raags
# Start user BettyLwellyn
# Finished user BettyLwellyn
# Start user TylerHaynes_
# Finished user TylerHaynes_
# Start user travellerjc
# Finished user travellerjc
# Start user becki139
# Finished user becki139
# Start user RawlTan
# Finished user RawlTan
# Start user ThorsHelm
# Finished user ThorsHelm
# Start user wild_dodo22
# Finished user wild_dodo22
# Start user Practical-Finance996
# Finished user Practical-Finance996
# Start user vegass67
# Finished user vegass67
# Start user SeerPumpkin
# Finished user SeerPumpkin
# Start user the_Leshiy
# Finished user the_Leshiy
# Start user Individual_Sun8462
# Finished user Individual_Sun8462
# Start user Clear_Dragonfruit323
# Finished user Clear_Dragonfruit323
# Start user _MambaForever
# Finished user _MambaForever
# Start user brett174
# Finished user brett174
# Start user talkytoucany
# Finished user talkytoucany
# Start user Minimum-Paper8652
# Finished user Minimum-Paper8652
# Start user kittooo_
# Finished user kittooo_
# Start user mike_hawk7
# Finished user mike_hawk7
# Start user angeddd
# Finished user angeddd
# Start user 71blackbird3
# Finished user 71blackbird3
# Start user parkingtriangle
# Finished user parkingtriangle
# Start user Haunting-Passenger99
# Finished user Haunting-Passenger99
# Start user Responsible-Algae461
# Finished user Responsible-Algae461
# Start user reeln166a
# Finished user reeln166a
# Start user jmkul
# Finished user jmkul
# Start user trail-barista
# Finished user trail-barista
# Start user lichnag
# Finished user lichnag
# Start user squatting_your_attic
# Finished user squatting_your_attic
# Start user WaluigiWahshipper
# Finished user WaluigiWahshipper
# Start user jeninwhis2704
# Finished user jeninwhis2704
# Start user Electric-Backslap
# Finished user Electric-Backslap
# Start user Revolutionary_Bus556
# Finished user Revolutionary_Bus556
# Start user synapsisxx
# Finished user synapsisxx
# Start user millsa_acm
# Finished user millsa_acm
# Start user josh_1112
# Finished user josh_1112
# Start user SoggyBiscuitVet
# Finished user SoggyBiscuitVet
# Start user firesonatlas
# Finished user firesonatlas
# Start user limasxgoesto0
# Finished user limasxgoesto0
# Start user LavineX
# Finished user LavineX
# Start user Toc001
# Finished user Toc001
# Start user sadgrad2
# Finished user sadgrad2
# Start user Redberet_
# Finished user Redberet_
# Start user mhks
# Finished user mhks
# Start user Grouchy_Chemical1087
# Finished user Grouchy_Chemical1087
# Start user LilienSixx
# Finished user LilienSixx
# Start user Ok_Yogurtcloset2398
# Finished user Ok_Yogurtcloset2398
# Start user DismalObjective136
# Finished user DismalObjective136
# Start user osakaskade
# Finished user osakaskade
# Start user Miserable_Craft_9178
# Finished user Miserable_Craft_9178
# Start user TIGMSDV1207
# Finished user TIGMSDV1207
# Start user Kebabme
# Finished user Kebabme
# Start user stopspammingme
# Finished user stopspammingme
# Start user Josquius
# Finished user Josquius
# Start user GreatWhiteGobbo
# Finished user GreatWhiteGobbo
# Start user Jarden_Nahgallac
# Finished user Jarden_Nahgallac
# Start user droim
# Finished user droim
# Start user reddit__is_fun
# Finished user reddit__is_fun
# Start user trysca
# Finished user trysca
# Start user NinjaElectricMeteor
# Finished user NinjaElectricMeteor
# Start user cuppa-t42
# Finished user cuppa-t42
# Start user schnellerv8
# Finished user schnellerv8
# Start user Saltedline
# Finished user Saltedline
# Start user 4th_and_26
# Finished user 4th_and_26
# Start user I_D0nt_pay_taxes
# Finished user I_D0nt_pay_taxes
# Start user MopCoveredInBleach
# Finished user MopCoveredInBleach
# Start user jeckles
# Finished user jeckles
# Start user anastasiusveronensis
# Finished user anastasiusveronensis
# Start user birorichard36
# Finished user birorichard36
# Start user Junior-Tangelo-9565
# Finished user Junior-Tangelo-9565
# Start user amandapanda740
# Finished user amandapanda740
# Start user DoThe_Funni69
# Finished user DoThe_Funni69
# Start user Sch3ma
# Finished user Sch3ma
# Start user Dust_Royal
# Finished user Dust_Royal
# Start user BiggieCheese_49
# Finished user BiggieCheese_49
# Start user azu_rill
# Finished user azu_rill
# Start user biwook
# Finished user biwook
# Start user KevWithADot
# Finished user KevWithADot
# Start user fatty__boi
# Finished user fatty__boi
# Start user randommstudent
# Finished user randommstudent
# Start user longwaytotokyo
# Finished user longwaytotokyo
# Start user Comfortable_Low_4317
# Finished user Comfortable_Low_4317
# Start user Goblin_Token
# Finished user Goblin_Token
# Start user Mackelowsky
# Finished user Mackelowsky
# Start user crubiom
# Finished user crubiom
# Start user shigeons
# Finished user shigeons
# Start user M1ttIII
# Finished user M1ttIII
# Start user rx303
# Finished user rx303
# Start user Phd_holder_guy
# Finished user Phd_holder_guy
# Start user Dimalen
# Finished user Dimalen
# Start user EvoSP1100
# Finished user EvoSP1100
# Start user userfromouterspace
# Finished user userfromouterspace
# Start user Midnight-Mustang
# Finished user Midnight-Mustang
# Start user AkaGurGor
# Finished user AkaGurGor
# Start user monnemhtr
# Finished user monnemhtr
# Start user eskasy
# Finished user eskasy
# Start user princess-sewerslide
# Finished user princess-sewerslide
# Start user cesarth15
# Finished user cesarth15
# Start user gravityandgrrace
# Finished user gravityandgrrace
# Start user karsll
# Finished user karsll
# Start user Jeccg
# Finished user Jeccg
# Start user geiselweisel
# Finished user geiselweisel
# Start user SCTxrp
# Finished user SCTxrp
# Start user loqbox
# Finished user loqbox
# Start user 0dimension1
# Finished user 0dimension1
# Start user IReadUtoTheFilth
# Finished user IReadUtoTheFilth
# Start user officialsunday
# Finished user officialsunday
# Start user cesqret
# Finished user cesqret
# Start user Hanfugirl
# Finished user Hanfugirl
# Start user Depressedzoomer531
# Finished user Depressedzoomer531
# Start user BrutalAsFuck
# Finished user BrutalAsFuck
# Start user Comrade_Jane_Jacobs
# Finished user Comrade_Jane_Jacobs
# Start user Divinesteel
# Finished user Divinesteel
# Start user elbotmania
# Finished user elbotmania
# Start user RagingSuperSaiyan
# Finished user RagingSuperSaiyan
# Start user ads_1105
# Finished user ads_1105
# Start user Diemmedi
# Finished user Diemmedi
# Start user Utertoq
# Finished user Utertoq
# Start user see-137
# Finished user see-137
# Start user muffin-butter
# Finished user muffin-butter
# Start user g0ddeshenta1
# Finished user g0ddeshenta1
# Start user ShanestudiosYT
# Finished user ShanestudiosYT
# Start user Anxious-Lock9331
# Finished user Anxious-Lock9331
# Start user TheRookieGetsACookie
# Finished user TheRookieGetsACookie
# Start user Chesspatch
# Finished user Chesspatch
# Start user MoonlightWolf
# Finished user MoonlightWolf
# Start user LuisE3Oliveira
# Finished user LuisE3Oliveira
# Start user sleepsamurai
# Finished user sleepsamurai
# Start user Wandering_Mobiler
# Finished user Wandering_Mobiler
# Start user pedrohenrlc
# Finished user pedrohenrlc
# Start user rombopterix
# Finished user rombopterix
# Start user aughtmarketers
# Finished user aughtmarketers
# Start user Electriczzx
# Finished user Electriczzx
# Start user Direct_Ticket4105
# Finished user Direct_Ticket4105
# Start user abbubbuee
# Finished user abbubbuee
# Start user ann_1608
# Finished user ann_1608
# Start user Ilmara
# Finished user Ilmara
# Start user Haunting_Reindeer183
# Finished user Haunting_Reindeer183
# Start user baltosteve
# Finished user baltosteve
# Start user di_abolus
# Finished user di_abolus
# Start user medico-dingo
# Finished user medico-dingo
# Start user chillandshyhmu
# Finished user chillandshyhmu
# Start user finndsoost
# Finished user finndsoost
# Start user lcdabest
# Finished user lcdabest
# Start user ahmedsalaheldin
# Finished user ahmedsalaheldin
# Start user jjhoansen
# Finished user jjhoansen
# Start user pur__0_0__
# Finished user pur__0_0__
# Start user EliaTassoni
# Finished user EliaTassoni
# Start user ProAidin101
# Finished user ProAidin101
# Start user Interesting_Age_847
# Finished user Interesting_Age_847
# Start user Legitimate_Ad8917
# Finished user Legitimate_Ad8917
# Start user Sandrunez
# Finished user Sandrunez
# Start user Upbeat-Flamingo-5811
# Finished user Upbeat-Flamingo-5811
# Start user rollerbladeshoes
# Finished user rollerbladeshoes
# Start user maninahat
# Finished user maninahat
# Start user alenchek
# Finished user alenchek
# Start user lys28
# Finished user lys28
# Start user South-Satisfaction69
# Finished user South-Satisfaction69
# Start user ICallThisBullshit
# Finished user ICallThisBullshit
# Start user _0-_-0-_-0_
# Finished user _0-_-0-_-0_
# Start user JeanGarsbien
# Finished user JeanGarsbien
# Start user GearDown22
# Finished user GearDown22
# Start user dr3wfr4nk
# Finished user dr3wfr4nk
# Start user rileyphone
# Finished user rileyphone
# Start user illnvrstpmywndrng1
# Finished user illnvrstpmywndrng1
# Start user Diamond151
# Finished user Diamond151
# Start user dark_moods
# Finished user dark_moods
# Start user davidvietro
# Finished user davidvietro
# Start user CaseyGuo
# Finished user CaseyGuo
# Start user rzet
# Finished user rzet
# Start user devil-_-cries
# Finished user devil-_-cries
# Start user e9967780
# Finished user e9967780
# Start user hpx93
# Finished user hpx93
# Start user munuzus
# Finished user munuzus
# Start user Frennauta
# Finished user Frennauta
# Start user usermatts
# Finished user usermatts
# Start user UpperFrontalButtocks
# Finished user UpperFrontalButtocks
# Start user Expensive-Team7416
# Finished user Expensive-Team7416
# Start user francishg
# Finished user francishg
# Start user OkBasil_147
# Finished user OkBasil_147
# Start user sideone
# Finished user sideone
# Start user riktigaglobby
# Finished user riktigaglobby
# Start user Sad_Advertising4036
# Finished user Sad_Advertising4036
# Start user Apart_Emergency_191
# Finished user Apart_Emergency_191
# Start user somo1230
# Finished user somo1230
# Start user RockyMahato
# Finished user RockyMahato
# Start user whateverman37
# Finished user whateverman37
# Start user whitecollarpizzaman
# Finished user whitecollarpizzaman
# Start user Donstap
# Finished user Donstap
# Start user genrube
# Finished user genrube
# Start user YoungRichKid
# Finished user YoungRichKid
# Start user Slam123456
# Finished user Slam123456
# Start user alaskarfox
# Finished user alaskarfox
# Start user ti89-calculator
# Finished user ti89-calculator
# Start user underwater_handshake
# Finished user underwater_handshake
# Start user meiyoumeiyou
# Finished user meiyoumeiyou
# Start user sillahillone
# Finished user sillahillone
# Start user GreenWolfyVillager
# Finished user GreenWolfyVillager
# Start user tisto_
# Finished user tisto_
# Start user Some_Adhesiveness513
# Finished user Some_Adhesiveness513
# Start user Spascucci
# Finished user Spascucci
# Start user gabigolterasga
# Finished user gabigolterasga
# Start user Jsigel
# Finished user Jsigel
# Start user SOM3HOWiMANAGE
# Finished user SOM3HOWiMANAGE
# Start user gavarnie
# Finished user gavarnie
# Start user avalonfire
# Finished user avalonfire
# Start user Enough-Engineering41
# Finished user Enough-Engineering41
# Start user g4hlore
# Finished user g4hlore
# Start user theknowndudereturns
# Finished user theknowndudereturns
# Start user Mundane-Alfalfa-8979
# Finished user Mundane-Alfalfa-8979
# Start user dylancatlow
# Finished user dylancatlow
# Start user Coeur44300
# Finished user Coeur44300
# Start user HA_JB
# Finished user HA_JB
# Start user DragonXDT
# Finished user DragonXDT
# Start user Proculos
# Finished user Proculos
# Start user alfredokurdi
# Finished user alfredokurdi
# Start user Elaies
# Finished user Elaies
# Start user thatBOOMBOOMguy
# Finished user thatBOOMBOOMguy
# Start user -FaZe-
# Finished user -FaZe-
# Start user tatv_047
# Finished user tatv_047
# Start user AlexxBoo_1
# Finished user AlexxBoo_1
# Start user dilip_che
# Finished user dilip_che
# Start user polodroid74
# Finished user polodroid74
# Start user Kuharu
# Finished user Kuharu
# Start user Tiny_Designer4777
# Finished user Tiny_Designer4777
# Start user banksiabush1988
# Finished user banksiabush1988
# Start user Practical_Candy4019
# Finished user Practical_Candy4019
# Start user NewJeff6016
# Finished user NewJeff6016
# Start user 17O8
# Finished user 17O8
# Start user demolition12354
# Finished user demolition12354
# Start user Feebedel324
# Finished user Feebedel324
# Start user talude
# Finished user talude
# Start user M41Bulldog
# ...
# Finished user thawingSumTendies
# Start user loyaltodark
# Finished user loyaltodark
# Start user Anmithge1234
# Finished user Anmithge1234
# Start user StickAFork
# Finished user StickAFork
# Start user harisaduu
# Finished user harisaduu
# Start user JulesHaggard
# Finished user JulesHaggard
# Start user ShadowBannedAugustus
# Finished user ShadowBannedAugustus
# Start user M795
# Finished user M795
# Start user CreepySniper94
# Finished user CreepySniper94
# Start user pipsdontsqueak
# Finished user pipsdontsqueak
# Start user lazydesignerartist
# Finished user lazydesignerartist
# Start user Adventurous-Belt4452
# Finished user Adventurous-Belt4452
# Start user Carryneo
# Finished user Carryneo
# Start user GeoPoliticsMyThang11
# Finished user GeoPoliticsMyThang11
# Start user jimmurphysf
# Finished user jimmurphysf
# Start user thegram16
# Finished user thegram16
# Start user No_Wishbone_1629
# Finished user No_Wishbone_1629
# Start user rapps55
# Finished user rapps55
# Start user nazaninabolfadl
# Finished user nazaninabolfadl
# Start user reuters
# Finished user reuters
# Start user Young_Englander
# Finished user Young_Englander
# Start user redcccp
# Finished user redcccp
# Start user DutchTechJunkie
# Finished user DutchTechJunkie
# Start user DougSeeger
# Finished user DougSeeger
# Start user BernFrere
# Finished user BernFrere
# Start user Into-the-stream
# Finished user Into-the-stream
# Start user stepover7
# Finished user stepover7
# Start user jjjhkvan
# Finished user jjjhkvan
# Start user JayR_97
# Finished user JayR_97
# Start user YosemiteVagrant
# Finished user YosemiteVagrant
# Start user APnews
# Finished user APnews
# Start user raytaylor
# Finished user raytaylor
# Start user vegetarianrobots
# Finished user vegetarianrobots
# Start user Bozzooo
# Finished user Bozzooo
# Start user roboterm
# Finished user roboterm
# Start user Zealousideal-Ask4232
# Finished user Zealousideal-Ask4232
# Start user 1000000students
# Finished user 1000000students
# Start user silasgreenfront
# Finished user silasgreenfront
# Start user deadpools0
# Finished user deadpools0
# Start user Izaac4
# Finished user Izaac4
# Start user 457655676
# Finished user 457655676
# Start user MindWithEase
# Finished user MindWithEase
# Start user 9lobaldude
# Finished user 9lobaldude
# Start user pivovy
# Finished user pivovy
# Start user TestTossTestToss2
# Finished user TestTossTestToss2
# Start user Seek_Adventure
# Finished user Seek_Adventure
# Start user MattGald
# Finished user MattGald
# Start user flawedwithvice
# Finished user flawedwithvice
# Start user morenewsat11
# Finished user morenewsat11
# Start user eeby_deeby
# Finished user eeby_deeby
# Start user chippychipper444
# Finished user chippychipper444
# Start user HowAboutThisNameNow
# Finished user HowAboutThisNameNow
# Start user progmakerlt
# Finished user progmakerlt
# Start user koi-lotus-water-pond
# Finished user koi-lotus-water-pond
# Start user devvls
# Finished user devvls
# Start user ead09
# Finished user ead09
# Start user 9Wind
# Finished user 9Wind
# Start user ontrack
# Finished user ontrack
# Start user IceLongjumping1866
# Finished user IceLongjumping1866
# Start user Ilikemovies1
# Finished user Ilikemovies1
# Start user NewTitus
# Finished user NewTitus
# Start user EagleEyeStx
# Finished user EagleEyeStx
# Start user RandomForks
# Finished user RandomForks
# Start user Acrobatic_Effect4907
# Finished user Acrobatic_Effect4907
# Start user so2017
# Finished user so2017
# Start user epsd101
# Finished user epsd101
# Start user TravelingRob
# Finished user TravelingRob
# Start user koolman631
# Finished user koolman631
# Start user Nvnv_man
# Finished user Nvnv_man
# Start user Interrete
# Finished user Interrete
# Start user omgsubway
# Finished user omgsubway
# Start user DarthNihilus_501st
# Finished user DarthNihilus_501st
# Start user Taco-Dragon
# Finished user Taco-Dragon
# Start user visope
# Finished user visope
# Start user JACK_DAGNIELS
# Finished user JACK_DAGNIELS
# Start user RuseOwl
# Finished user RuseOwl
# Start user martijnlv40
# Finished user martijnlv40
# Start user candagltr
# Finished user candagltr
# Start user SoUnProfessional
# Finished user SoUnProfessional
# Start user th3Raziel
# Finished user th3Raziel
# Start user linusdropstech
# Finished user linusdropstech
# Start user FrankFFrankie
# Finished user FrankFFrankie
# Start user nick313
# Finished user nick313
# Start user TheDarthSnarf
# Finished user TheDarthSnarf
# Start user LogicB0mbs
# Finished user LogicB0mbs
# Start user MassDefect36
# Finished user MassDefect36
# Start user FYoCouchEddie
# Finished user FYoCouchEddie
# Start user Hassanvhr02
# Finished user Hassanvhr02
# Start user zenonidenoni
# Finished user zenonidenoni
# Start user polymute
# Finished user polymute
# Start user gordon22
# Finished user gordon22
# Start user HauntingJackfruit
# Finished user HauntingJackfruit
# Start user PJJefferson
# Finished user PJJefferson
# Start user Cumberbound
# Finished user Cumberbound
# Start user NamelessForce
# Finished user NamelessForce
# Start user Thick-Pumpkin5075
# Finished user Thick-Pumpkin5075
# Start user SgtPup
# Finished user SgtPup
# Start user rolandopax
# Finished user rolandopax
# Start user Amax2
# Finished user Amax2
# Start user FartsWithAnAccent
# Finished user FartsWithAnAccent
# Start user xeno132
# Finished user xeno132
# Start user Foolishly_Sane
# Finished user Foolishly_Sane
# Start user Exciting_Issue7173
# Finished user Exciting_Issue7173
# Start user krstofffa
# Finished user krstofffa
# Start user KasaneTeto_
# Finished user KasaneTeto_
# Start user A_Lag_Beast
# Finished user A_Lag_Beast
# Start user Mister_Keyyy
# Finished user Mister_Keyyy
# Start user StylishQuick
# Finished user StylishQuick
# Start user EuraTyson
# Finished user EuraTyson
# Start user Bullettoothtony308
# Finished user Bullettoothtony308
# Start user BeigeListed
# Finished user BeigeListed
# Start user MitziKino1
# Finished user MitziKino1
# Start user Lil_Peachy_Fox
# Finished user Lil_Peachy_Fox
# Start user MoffBlonde
# Finished user MoffBlonde
# Start user ava_palindrome
# Finished user ava_palindrome
# Start user Lesterenny
# Finished user Lesterenny
# Start user Yachtsbabyyachts
# Finished user Yachtsbabyyachts
# Start user smolrug
# Finished user smolrug
# Start user speedwoof112
# Finished user speedwoof112
# Start user Bored_but_curious
# Finished user Bored_but_curious
# Start user Fernerer
# Finished user Fernerer
# Start user No-Analyst2
# Finished user No-Analyst2
# Start user _haha_oh_wow_
# Finished user _haha_oh_wow_
# Start user SlowVisual9
# Finished user SlowVisual9
# Start user HannahSwane
# Finished user HannahSwane
# Start user MattUWayne
# Finished user MattUWayne
# Start user LordoftheJives
# Finished user LordoftheJives
# Start user Doodle__Noodle_
# Finished user Doodle__Noodle_
# Start user LoudlyInborn
# Finished user LoudlyInborn
# Start user machan12
# Finished user machan12
# Start user NicktheDouglas
# Finished user NicktheDouglas
# Start user ericadias
# Finished user ericadias
# Start user MarsheilaKS
# Finished user MarsheilaKS
# Start user MiterMinister
# Finished user MiterMinister
# Start user StatusVirus1970
# Finished user StatusVirus1970
# Start user sf1999
# Finished user sf1999
# Start user Samcanram
# Finished user Samcanram
# Start user absolutepollocks
# Finished user absolutepollocks
# Start user damokres
# Finished user damokres
# Start user Ben_hodgson
# Finished user Ben_hodgson
# Start user Fit_Manufacturer_788
# Finished user Fit_Manufacturer_788
# Start user Parking_Courage1970
# Finished user Parking_Courage1970
# Start user raibsta
# Finished user raibsta
# Start user ARREST_HILLARY_NOW
# Finished user ARREST_HILLARY_NOW
# Start user Far-Mycologist7339
# Finished user Far-Mycologist7339
# Start user mtrash
# Finished user mtrash
# Start user InternationalForm3
# Finished user InternationalForm3
# Start user Cupcake_Shake
# Finished user Cupcake_Shake
# Start user Certified-Crackhead
# Finished user Certified-Crackhead
# Start user JoeyBagOWaffles
# Finished user JoeyBagOWaffles
# Start user wondermintcake
# Finished user wondermintcake
# Start user jsnev97
# Finished user jsnev97
# Start user miss3xcom
# Finished user miss3xcom
# Start user MiaOlsonXOXO
# Finished user MiaOlsonXOXO
# Start user Dan_Backslide_III
# Finished user Dan_Backslide_III
# Start user my-dick-is-a-girl
# Finished user my-dick-is-a-girl
# Start user pabloperezolo
# Finished user pabloperezolo
# Start user ShutUpRedditor44
# Finished user ShutUpRedditor44
# Start user Fariaszs
# Finished user Fariaszs
# Start user braydnfps
# Finished user braydnfps
# Start user Not_callizer
# Finished user Not_callizer
# Start user FusKiinDov
# Finished user FusKiinDov
# Start user ox_krisis
# Finished user ox_krisis
# Start user No_Comfortable7396
# Finished user No_Comfortable7396
# Start user DoubleItAll
# Finished user DoubleItAll
# Start user Newlife1025
# Finished user Newlife1025
# Start user sybersonic
# Finished user sybersonic
# Start user Bennybennymahaalo
# Finished user Bennybennymahaalo
# Start user Bristlemedr
# Finished user Bristlemedr
# Start user DRUPEN
# Finished user DRUPEN
# Start user Gezn2inexile
# Finished user Gezn2inexile
# Start user limpforks
# Finished user limpforks
# Start user WolfedWhale
# Finished user WolfedWhale
# Start user fr0gznotfound
# Finished user fr0gznotfound
# Start user BannedFrom_rPolitics
# Finished user BannedFrom_rPolitics
# Start user Joearzubu
# Finished user Joearzubu
# Start user Im6ftToo
# Finished user Im6ftToo
# Start user bowkitty666
# Finished user bowkitty666
# Start user Schlumcity
# Finished user Schlumcity
# Start user spicymellohi
# Finished user spicymellohi
# Start user Kenkiedits
# Finished user Kenkiedits
# Start user fastcarsandfreedom
# Finished user fastcarsandfreedom
# Start user Sixpacksack
# Finished user Sixpacksack
# Start user CalmAverage7
# Finished user CalmAverage7
# Start user sataniccpanic
# Finished user sataniccpanic
# Start user Horst93Walter
# Finished user Horst93Walter
# Start user CremeMaleficent4149
# Finished user CremeMaleficent4149
# Start user birdyisno
# Finished user birdyisno
# Start user Technical-Fuel-3856
# Finished user Technical-Fuel-3856
# Start user JustWinning733
# Finished user JustWinning733
# Start user CorrectHealthy
# Finished user CorrectHealthy
# Start user Bisexualfreak418d
# Finished user Bisexualfreak418d
# Start user Junj1e
# Finished user Junj1e
# Start user SomeDudeist
# Finished user SomeDudeist
# Start user armaan0314
# Finished user armaan0314
# Start user ricardosaucedealr
# Finished user ricardosaucedealr
# Start user Notsohiddenfox
# Finished user Notsohiddenfox
# Start user alidreamx
# Finished user alidreamx
# Start user AdFar6377
# Finished user AdFar6377
# Start user SyntheticWaifu
# Finished user SyntheticWaifu
# Start user kaijufumetsu
# Finished user kaijufumetsu
# Start user camraaaa
# Finished user camraaaa
# Start user TheToenailGuy
# Finished user TheToenailGuy
# Start user TheNotSoSocialUser
# Finished user TheNotSoSocialUser
# Start user zreich4
# Finished user zreich4
# Start user realprettyangel
# Finished user realprettyangel
# Start user ExtremeProduce9147
# Finished user ExtremeProduce9147
# Start user Fit-Bluebird9803
# Finished user Fit-Bluebird9803
# Start user AggravatingOnDot
# Finished user AggravatingOnDot
# Start user bucket_of_dogs
# Finished user bucket_of_dogs
# Start user CommercialAttorney90
# Finished user CommercialAttorney90
# Start user Gothalla123
# Finished user Gothalla123
# Start user Zephyrzephan
# Finished user Zephyrzephan
# Start user gn3xu5
# Finished user gn3xu5
# Start user Due_Ad_9925
# Finished user Due_Ad_9925
# Start user sub_gastenpower
# Finished user sub_gastenpower
# Start user snapmaidens
# Finished user snapmaidens
# Start user ragingblackbears
# Finished user ragingblackbears
# Start user MonikaKingaa
# Finished user MonikaKingaa
# Start user GojiraMan5422
# Finished user GojiraMan5422
# Start user maarsarcogenicu5
# Finished user maarsarcogenicu5
# Start user Allyllj
# Finished user Allyllj
# Start user celina585
# Finished user celina585
# Start user allperson
# Finished user allperson
# Start user aviboyko
# Finished user aviboyko
# Start user shortypants
# Finished user shortypants
# Start user MuchHigherKnowledge
# Finished user MuchHigherKnowledge
# Start user SubstantialCelery699
# Finished user SubstantialCelery699
# Start user Whowhatwhynguyen
# Finished user Whowhatwhynguyen
# Start user SeaworthinessOky
# Finished user SeaworthinessOky
# Start user Kirorga
# Finished user Kirorga
# Start user Andrea_Summer54
# Finished user Andrea_Summer54
# Start user HowBoutaLittlePiss
# Finished user HowBoutaLittlePiss
# Start user Voidthug
# Finished user Voidthug
# Start user Lolakittens
# Finished user Lolakittens
# Start user throwra__172
# Finished user throwra__172
# Start user Star-Lord5
# Finished user Star-Lord5
# Start user supercooljoe01
# Finished user supercooljoe01
# Start user saadesigner
# Finished user saadesigner
# Start user PerfectDrawing4370
# Finished user PerfectDrawing4370
# Start user Jacaxagain
# Finished user Jacaxagain
# Start user FuzzyCrocks
# Finished user FuzzyCrocks
# Start user Freddik21
# Finished user Freddik21
# Start user young_wonderer
# Finished user young_wonderer
# Start user ThatMennoniteGal
# Finished user ThatMennoniteGal
# Start user KaitieSky
# Finished user KaitieSky
# Start user tanbo_theman
# Finished user tanbo_theman
# Start user chrisbeelike
# Finished user chrisbeelike
# Start user Lucca70
# Finished user Lucca70
# Start user TheZephyr07
# Finished user TheZephyr07
# Start user littlesheep_offf
# Finished user littlesheep_offf
# Start user Chocolatefuckdoll
# Finished user Chocolatefuckdoll
# Start user oddeilem
# Finished user oddeilem
# Start user Ok-Climate7571
# Finished user Ok-Climate7571
# Start user averiroselyn
# Finished user averiroselyn
# Start user Sapphyrexxx
# Finished user Sapphyrexxx
# Start user Goldenjayepic
# Finished user Goldenjayepic
# Start user WoafLiber9100
# Finished user WoafLiber9100
# Start user spicyramenslut
# Finished user spicyramenslut
# Start user future_maple
# Finished user future_maple
# Start user UnluckyJudgment8805
# Finished user UnluckyJudgment8805
# Start user just4_a_while
# Finished user just4_a_while
# Start user shibbitydibbity
# Finished user shibbitydibbity
# Start user VoraciousConsul
# Finished user VoraciousConsul
# Start user Hentailing
# Finished user Hentailing
# Start user Atomic_Dolls
# Finished user Atomic_Dolls
# Start user Standard_Finger_9070
# Finished user Standard_Finger_9070
# Start user Upstairs-Note8658
# Finished user Upstairs-Note8658
# Start user Xcolombian_mamiX
# Finished user Xcolombian_mamiX
# Start user Enter_Evolution
# Finished user Enter_Evolution
# Start user Ninjhetto
# Finished user Ninjhetto
# Start user ballsniffer232point0
# Finished user ballsniffer232point0
# Start user Street_Community_922
# Finished user Street_Community_922
# Start user Tim_enm
# Finished user Tim_enm
# Start user Lord-Maplefrost
# Finished user Lord-Maplefrost
# Start user IthinkiLy
# Finished user IthinkiLy
# Start user 1111110
# Finished user 1111110
# Start user crying-and-prejudice
# Finished user crying-and-prejudice
# Start user Gray69420
# Finished user Gray69420
# Start user ottaviia
# Finished user ottaviia
# Start user oh_ill_ask_alright
# Finished user oh_ill_ask_alright
# Start user Calm-Field9753
# Finished user Calm-Field9753
# Start user FALL1N1-
# Finished user FALL1N1-
# Start user fightingcobra8
# Finished user fightingcobra8
# Start user Shiraz0
# Finished user Shiraz0
# Start user MRVANCLEAVEREDDIT
# Finished user MRVANCLEAVEREDDIT
# Start user theranman3
# Finished user theranman3
# Start user immortalreddotmemeog
# Finished user immortalreddotmemeog
# Start user just-wondering98
# Finished user just-wondering98
# Start user skyeyemx
# Finished user skyeyemx
# Start user Zoggman
# Finished user Zoggman
# Start user EthDec
# Finished user EthDec
# Start user CubeFan12
# Finished user CubeFan12
# Start user Crafty-Reference-306
# Finished user Crafty-Reference-306
# Start user MissIss12
# Finished user MissIss12
# Start user Videogamer2719
# Finished user Videogamer2719
# Start user lol_Socks
# Finished user lol_Socks
# Start user Joselinelovee
# Finished user Joselinelovee
# Start user Touched_By_Nature
# Finished user Touched_By_Nature
# Start user chalk_in_boots
# Finished user chalk_in_boots
# Start user IronAchillesz
# Finished user IronAchillesz
# Start user theLaLiLuLeLol
# Finished user theLaLiLuLeLol
# Start user AnthropomorphicPoop
# Finished user AnthropomorphicPoop
# Start user Kid3v1
# Finished user Kid3v1
# Start user Jimmys_Paintings
# Finished user Jimmys_Paintings
# Start user brandnewnikes
# Finished user brandnewnikes
# Start user FarEastFox
# Finished user FarEastFox
# Start user Nairda-_-
# Finished user Nairda-_-
# Start user pumpin_jumpin
# Finished user pumpin_jumpin
# Start user Darnlljones
# Finished user Darnlljones
# Start user msbun
# Finished user msbun
# Start user samcon30
# Finished user samcon30
# end

# %%
# Print number of nodes and edges in the graph
print('Number of nodes:', graph.number_of_nodes())
print('Number of edges:', graph.number_of_edges())
# Out:
# Number of nodes: 23173
# Number of edges: 6877773

# %%
# Save the graph in GraphML format
nx.write_graphml(graph, 'Network.graphml')

# %%
# Draw the graph using NetworkX
fig, ax = plt.subplots(figsize=(12, 12))
pos = nx.spring_layout(graph, seed=42, k=3)  # set k parameter to 0.3 to increase distance between nodes
nx.draw_networkx_nodes(graph, pos, node_size=50, node_color='blue', alpha=0.5)
nx.draw_networkx_edges(graph, pos, edge_color='gray', alpha=0.5, width=2)
nx.draw_networkx_labels(graph, pos, font_size=8, font_family='sans-serif')
plt.axis('off')
# Save the graph as PNG image
plt.savefig('graph.png', format='png')

plt.show()
